# %% [markdown]
# # Visualize My Math

# %%
# Initialization
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %% [markdown]
# ### Part 1: *Funcions*

# %%
fig, axs = plt.subplots(5, 2, figsize=(10, 20), constrained_layout=True)

x = np.linspace(-10, 10, 20)
axs[0, 0].plot(x, x**2)
axs[0, 0].set_title(r'$y=x^2$')
axs[0, 0].axhline(0, color='black')
axs[0, 0].axvline(0, color='black')

x = np.linspace(-10, 10, 90)
axs[0, 1].plot(x, 1/x)
axs[0, 1].set_title(r'$y=\frac{1}{x}$')
axs[0, 1].axhline(0, color='black')
axs[0, 1].axvline(0, color='black')

x = np.linspace(0, 10, 100)
axs[1, 0].plot(x, x**(1/2))
axs[1, 0].set_title(r'$y=\sqrt{x}$')
axs[1, 0].axhline(0, color='black')
axs[1, 0].axvline(0, color='black')

x = np.linspace(-10, 4, 100)
axs[1, 1].plot(x, np.sqrt(4-x))
axs[1, 1].set_title(r'$y=\sqrt{4-x}$')
axs[1, 1].axhline(0, color='black')
axs[1, 1].axvline(0, color='black')

x = np.linspace(-1, 1, 50)
axs[2, 0].plot(x, np.sqrt(1-x**2))
axs[2, 0].set_title(r'$y=\sqrt{1-x^2}$')
axs[2, 0].axhline(0, color='black')
axs[2, 0].axvline(0, color='black')

# Add here
x = np.linspace(-10, 4, 100)
axs[2, 1].plot(x, np.sqrt(4-x))
axs[2, 1].set_title(r'$y=\sqrt{4-x}$')
axs[2, 1].axhline(0, color='black')
axs[2, 1].axvline(0, color='black')

x = np.linspace(-3*np.pi, 3*np.pi, 100)
axs[3, 0].plot(x, np.sin(x))
axs[3, 0].set_title(r'$y=sin(x)$')
axs[3, 0].axhline(0, color='black')
axs[3, 0].axvline(0, color='black')

x = np.linspace(-2*np.pi, 2*np.pi, 100)
axs[3, 1].plot(x, np.tan(x))
axs[3, 1].set_ylim(-5, 5)
axs[3, 1].set_title(r'$y=tan(x)$')
axs[3, 1].axhline(0, color='black')
axs[3, 1].axvline(0, color='black')

x = np.linspace(-3*np.pi, 3*np.pi, 100)
axs[4, 0].plot(x, np.cos(x))
axs[4, 0].set_title(r'$y=cos(x)$')
axs[4, 0].axhline(0, color='black')
axs[4, 0].axvline(0, color='black')

# %%
# Visualizing Integrations and Derivatives
x = np.linspace(-10, 10, 100)

fig = plt.figure(figsize=(15, 30), dpi=80)
plt.plot(x, x**2)
plt.plot(x, (x**3)/3)
plt.plot(x, (x**4)/12)
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.ylim(-100, 100)
ax = plt.gca()
ax.set_aspect(0.1)

plt.annotate(r'$y=x^2$', xy=(0, 0), xytext=(8.47, 90), fontsize=14)
plt.annotate(r'$y= \frac{x^3}{3}$', xy=(0, 0), xytext=(5.45, 90), fontsize=14)
plt.annotate(r'$y= \frac{x^4}{12}$', xy=(0, 0), xytext=(4.5, 80), fontsize=14)
# Out:
# Text(4.5, 80, '$y= \\frac{x^4}{12}$')
